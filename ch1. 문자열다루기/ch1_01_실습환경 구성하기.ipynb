# %% [markdown]
# ## **텍스트마이닝(윤상혁 교수)**
# ## ch1. 파이썬 기초
# ## ch1_01. 실습환경 구성하기
#
#
# ---

# %% [markdown]
# ## 0. 기본환경 구성하기

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 1. Google Drive로 이동
# 2. +새로만들기 (New) 클릭
# 3. 더보기 - 연결할 앱 더보기 클릭
# 4. Colaboratory 검색
# 5. "추가" 버튼 클릭하기

# %% [markdown]
# ## **Colab 이란?**
# # Google Colaboratory의 줄임말
#
# 구글에서 **교육과 과학 연구를 목적**으로 개발한 도구로, 2017년에 무료로 공개하였습니다.
#
# ### 장점
# 1. 무료
# 2. 구글 드라이브와 연동 가능
# 3. GPU를 사용할 수 있음
# 4. 데이터 분석 절차에 맞게 셀 별 결과를 확인할 수 있음
# 5. 손 쉽게 타인과 공유할 수 있음
# 6. 생성형AI (Gemini)와 연동되어 있음
#
#
# ### 단점
# 1. 90분동안 아무런 인터액션이 없거나 (idle timeout), 12시간의 ***세션 타임아웃***이 존재함
# 2. GPU는 할당을 못받을 수도 있음 (혹은 빼앗기는 경우도 있음)
# 3. 조금 느림

# %% [markdown]
# ## 1. Colab 기본 메뉴 설명

# %% [markdown]
# 1. 목차
# 2. 파일 탐색기
# 3. 할당 여부 확인 하기 (RAM/디스크)
# 4. 댓글 (전체 파일에 대하여 / 셀에 대하여)

# %% [markdown]
# ### 1-1. GPU 사용하기

# %% [markdown]
# 수정 -> 노트 설정 -> 하드웨어 가속기 -> GPU 설정

# %% [markdown]
# ## 2. 실습파일 공유하기

# %% [markdown]
# ### 공유받은 colab을 읽기 전용 → 쓰기로 출력하기

# %% [markdown]
# 1. 파일 - 드라이브에 사본 저장을 클릭하여 "내 드라이브"에 추가 한니다
# 2. 파일 - Locate in Drive (드라이브 위치)에서 확인을 클릭 (파일의 저장 위치 확인 가능)

# %% [markdown]
# ### 내가 작성한 파일을 다른 사람과 공유하기

# %% [markdown]
# 우측 상단에 "공유" 버튼을 클릭하여, 공유가능하며, 링크로 전달 할 수 있다.
#
# **※ 공유 받은 사람이 쓰기 권한이 있으면, 파일이 수정될 수 있으니, 유의하세요**

# %% [markdown]
# ## 3. 셀의 종류 (코드와 텍스트)

# %% [markdown]
# 코드 셀: 코드 실행을 위한 셀

# %% [markdown]
# 텍스트 셀: 주석을 달거나, 설명 문구등을 달기 위한 텍스트 전용 셀

# %% [markdown]
# ### 4-1. 주석과 텍스트 셀의 차이

# %% [markdown]
# 코드셀 설명입니다.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# print("Hello world")

# %%
#print("Hello world")
print("안녕하세요")
# Out:
# 안녕하세요

# %%
# 출력연습
# Out:
# 안녕하세요

# %%
#주석입니다
print("안녕하세요")
# Out:
# 안녕하세요

# %% [markdown]
# 안녕하세요!

# %% [markdown]
# 이것은 텍스트 셀입니다

# %%
# 주석입니다.
print('안녕하세요')

# 주석입니다.
print('안녕하세요')
# Out:
# 안녕하세요
# 안녕하세요

# %%
print('안녕하세요')
print("'안녕하세요'")
print("He's a students")
# Out:
# 안녕하세요
# '안녕하세요'
# He's a students

# %% [markdown]
# ### 4-2. 셀의 삽입 방법

# %% [markdown]
# 상단의 "+코드", "+텍스트"를 눌러서 삽입합니다

# %% [markdown]
# **[셀 추가 관련 단축키]**
#
# 1. 코드 셀 위에 삽입 (Ctrl/Cmd + M A)
# 2. 코드 셀 아래에 삽입 (Ctrl/Cmd + M B)

# %% [markdown]
# 텍스트

# %% [markdown]
# ### 4-3. 셀의 삭제 방법

# %% [markdown]
# 우측의 **휴지통 아이콘을 클릭**하여 삭제합니다.

# %% [markdown]
# **[셀 삭제 관련 단축키]**

# %% [markdown]
# 셀 지우기 (Ctrl/Cmd + M D)

# %%
print("Hello world")

# %% [markdown]
# ### 4-4 셀의 타입 변경

# %% [markdown]
# **[셀 타입 변경 단축키]**
# 1. 코드 셀로 변경 (Ctrl/Cmd + M Y)
# 2. 마크다운 셀로 변경 (Ctrl/Cmd + M M)
# 3. 방금 실행한 행위를 되돌리고 싶을 때 (Ctrl/Cmd + M Z)

# %%
print('안녕하세요')

# %% [markdown]
# ## 5. 실행과 출력

# %% [markdown]
# * **셀**: 실행의 단위
# * **실행**: 재생 버튼을 클릭하여, 실행 (해당 셀 실행)
# * **실행 순서**: *인터프리터 방식* 으로 실행하며, 순차적으로 메모리에 기억합니다.

# %% [markdown]
# **[실행 관련 단축키]**
#
# 1. 해당 셀을 실행하고 커서는 해당 셀  (Ctrl + Enter)
# 2. 해당 셀을 실행하고 커서는 다음 셀  (Shift + Enter)
# 3. 해당 셀을 실행하고 커서는 다음에 셀 삽입  (Alt + Enter)

# %%
print('안녕하세요1')
# Out:
# 안녕하세요1

# %%
print(1)
#print(2)
print(3)
# Out:
# 1
# 3

# %% [markdown]
# ## 6. 혹시 단축키를 모른다면?

# %% [markdown]
# Ctrl + M H (키보드 단축키 보기)

# %% [markdown]
# # 7. 기초 마크다운 문법
#
# Markdown(마크다운)이란 Markup(마크업)언어의 일종으로, **HTML경험이 없는 사람도 누구나 쉽게** 헤더,글 머리 기호,이미지 삽입, 링크, 글자 모양 등 다양한 서식을 쉽게 추가하는 방식의 문서 편집 문법이다.
#
#
# ***볼드처리***
# [링크 텍스트](https://)
#
# 1. 순서1
# 2. 순서1
# 3. 순서1
#
#
# * 순서없다
# * 순서없다
# * 순서없다

# %% [markdown]
# #안녕하세요
# ##안녕하세요
# **안녕하세요**

# %% [markdown]
# # 1.반갑습니다.
# ※ 목록(Tree) 구조 만들기 - # 활용

# %% [markdown]
# ## 1-1. 반갑습니다.

# %% [markdown]
# ### **1-1-1. 반갑습니다.**

# %% [markdown]
# *폰트 활용해보기*
#
# **폰트 활용해보기**
#
# ***폰트 활용해보기***

# %% [markdown]
# ## 8. 그 밖의 기능 - 이미지, Youtube 동영상, 웹사이트 로딩하기

# %%
from IPython.display import Image

# %%
from IPython.display import Image

# %%
Image('https://img.freepik.com/premium-photo/cute-adorable-persian-cat_567332-319.jpg')

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('EtE09lowIbk', 600, 480)

# %%
from IPython.display import HTML

# %%
HTML('https://datastudio.google.com/embed/reporting/d795eac4-ac08-4473-8841-738ea076d46e/page/1M')
# Out:
# <!DOCTYPE html><html lang="zh"><head><base href="/embed/"><meta http-equiv="X-UA-Compatible" content="IE=EDGE"/><meta http-equiv='content-type' content='text/html; charset=UTF-8'/><meta property="og:title" content="[Sample] Google Analytics Marketing Website 사본"/><meta property="og:type" content="article"/><meta property="og:url" content="http://datastudio.google.com/reporting/d795eac4-ac08-4473-8841-738ea076d46e/page/1M?feature=opengraph"/><meta property="og:image" content="http://datastudio.google.com/reporting/d795eac4-ac08-4473-8841-738ea076d46e/page/1M/thumbnail?sz=full&feature=opengraph"/><meta property="og:alt" content="[Sample] Google Analytics Marketing Website 사본"/><meta property="og:site_name" content="Google Data Studio"/><meta property="og:description" content="Google Data Studio turns your data into informative dashboards and reports that are easy to read, easy to share, and fully customizable."/><meta property="fb:app_id" content="272909363449265"/><link href="https://
# ...

# %% [markdown]
# ##AI를 활용한 코드 작성하기
#
#
#
# *   "코딩을 시작하거나 AI로 코드를 **생성**하세요"에서 **생성**버튼을 클릭하기
# *   우측 상단에 **Gemini** 버튼을 클릭하기
# * 과제:
#     1. 구구단을 출력하되, 매 단 마다 구분자(예:---)를 두고 사용자 입력을 받아서 "다음"이라고 치면 다음 단이 나오는 코드를 **직접** 작성하기
#     2. 구구단을 출력하되, 매 단 마다 구분자(예:---)를 두고 사용자 입력을 받아서 "다음"이라고 치면 다음 단이 나오는 코드를 **AI활용해서** 작성하기
